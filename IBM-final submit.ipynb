# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mohammad zamanzadeh**

# %% [markdown]
# *I am interested in data science because it allows you to recognize the pattern within the data and make inferences.*

# %% [markdown]
# ### In the cell below, even numbers (between 0 and 20) are stored in a list.

# %%
even_list = []
for i in range(20):
    if i % 2 == 0:
        even_list.append(i)

# %% [markdown]
# cognitive science include:
#    * artificial intelligence
#    * neuroscience
#    * psychology
#    * linguistics
#    * anthropology
#    * philosophy
#
# |               | accuracy      | AUC  |
# | ------------- |:-------------:| -----:|
# | model 1       | 0.80          | 0.60  |
# | model 2       | 0.87          | 0.78  |
# | model 3       | 0.66          | 0.58  |
#
# [My github address](https://github.com/zamanzadeh98)
